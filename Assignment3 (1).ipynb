# %% [markdown]
# 1. Build a simple webpage that displays text as shown in the below image

# %%
<DOCTYPE html>
<html lang="en">
<Head>
<title> displays text </title>
</Head>
<body>
<p><b>This text will be bolded</b> </p>
<p> <i> This text will be italic </i></p>
<p> <u> This text will be underlined </u></p>
<p> <mark> This text will be highlighted </mark></p>

<p> This is normal text <sup> This will be super script</sup> This is normal again </p>
<p> This is normal text <sub> This will be subscript</sub> </p>

<p> Normal Text <small>Small Text </small> </p>
<p> <del> This text will be deleted </del> </p>
</body>

</html>

# %% [markdown]
# 2.Build a simple webpage that helps users navigate different web development-related websites. Note: On
# clicking the hyperlink the web pages should open in a new tab. Below is a reference image.

# %%
<DOCTYPE html>
<html lang="en">
<Head>
<title> Hyperlink </title>
</Head>
<body>

<p> Take me to <a href="https://pwskills.com/" target="_blank"> PW Skills </a> to buy a course </p>

<p> Take me to <a href=" https://developer.mozilla.org/en-US/docs/Learn_web_development" target="_blank > MDN Docs </a> to know more about web development </p>

<p> Take me to <a href="https://lab.pwskills.com/" target="_blank > PW Skills Lab </a> to practice live coding </p>

</body>

</html>

# %% [markdown]
# 3.Build a simple blog web page with 3 pages home, web development, and web design. Each page must
# contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
# For the home page you can add some information about yourself?

# %%
<DOCTYPE html>
<html lang="en">
<head>
<title> Home </title>
</head>
<Body>
<a href="home.html"> Home </a> <br>
<a href="webdevelopment.html"> Web development </a> <br>
<a href="webdesign.html">  Web Design </a> <br>
<h1>
Welcome to My Website
</h1>
<p> My name is Aashish barman. Currently I'm living in Jaipur and working as a Admission counsellor.</p>
</body>
</html>

# %%
<DOCTYPE html>
<html lang="en">
<head>
<title> Web development </title>
</head>
<Body>
<a href="home.html"> Home </a> <br>
<a href="webdevelopment.html"> Web development </a> <br>
<a href="webdesign.html">  Web Design </a> <br>
<h1>
Introduction to Web Development
</h1>
<p> Web development encompasses the process of creating, building, and maintaining websites and web applications, including aspects like coding, programming, user experience (UX) design, and database management.</p>
</body>
</html>

# %%
<DOCTYPE html>
<html lang="en">
<head>
<title> Web Design </title>
</head>
<Body>
<a href="home.html"> Home </a> <br>
<a href="webdevelopment.html"> Web development </a> <br>
<a href="webdesign.html">  Web Design </a> <br>
<h1>
Welcome to Web Design
</h1>
<p> Web design is the process of creating the visual aspects and user experience of a website, encompassing elements like layout, color scheme.</p>
</body>
</html>

# %% [markdown]
# 7. Build a complex nested list structure representing a multi-level table of contents. Use unordered lists (<ul>) and list items (<li>) with inline-block styling to create a structured layout. Apply formatting tags to
# enhance the presentation of list items?

# %%
<!DOCTYPE html>
<html lang="en">
<head>
   <title> Nims University </title>
</head>
<body>
<h1> Table of Content </h1>
<ul>
   <li>
      Part 1: Introduction
   </li>
<li>
   Part 2: Getting Started
</li>
<ul style="list-style-type:circle;">
<li>2.1 Installing the software </li>
<li>2.2 Creating a new project </li>
<ul style="list-style-type:square;">
   <li >
      2.2.1 Project templates
   </li>
   <li>
      2.2.2 Customizing Setting
   </li>
</ul>
<li>2.3 Exploring the interface </li>
<ul style="list-style-type:square;">
<li>
   2.3.1 Toolbar Features
</li>
<li>
   2.3.2 Panel Layout
</li>
<ul style="list-style-type:square;">
<li>
   2.3.2.1 Docking Panel
</li>
<li>
   2.3.2.2 Tabbed interface
</li>
</ul>
</ul>
</ul>
<li>
   Part 3: Advanced Topics
</li>
<ul style="list-style-type:circle;">
<li>
   3.1 Working with Plugins
</li>
<ul style="list-style-type:square;">
<li>
   3.1.1 Installing with plugins
</li>
<li>
   3.1.2 Plugins with configuration
</li>
</ul>
<li>
   3.2 Customizing the UI
</li>
<ul style="list-style-type:square;">
   <li>
      3.2.1 Changing theme
   </li>
   <li>
      3.2.2 Configuring Shortcuts
   </li>
</ul>
<li>
   3.3 Optimizing performance
</li>
<ul style="list-style-type:square;">
<li>
   3.3.1 Caching Strategies
</li>
<li>
   3.3.2 Resources Minification
</li>
</ul>
</ul>
<li>
   Part 4 Conclusion
</li>
</ul>
</body>
</html>

# %% [markdown]
# 8. Create a table to display a conference schedule. Each row corresponds to a time slot, and each column
# corresponds to a room. Some time slots might have multiple sessions running simultaneously in different
# rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.
# (use table attribute “cellpadding”  to give extra padding in each table cell ).

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <title>Table</title>
</head>
<body>
    <h1>Table Conference</h1>
    <table border="1" cellpading="10" cellspacing="3">
        <tr>
            <th> Time </th>
            <th> Room 1 </th>
            <th> Room 2 </th>
            <th> Room 3 </th>
            <th> Room 4 </th>
        </tr>
        <tr>
            <td rowspan="3">9:00 AM - 10:00 AM </td>
            <td rowspan="2">Keynote</td>
            <td>Session A</td>
            <td>Session B</td>
            <td rowspan="3">Session C</td>
        </tr>
        <tr>
            <td>Session D</td>
            <td>Session E</td>
        </tr>
        <tr>
            <td>10:30 AM-11:30 AM</td>
            <td colspan="2">Session F</td>
        </tr>
        <tr>
            <td>12:00 PM - 1:00 PM </td>
            <td colspan="4">Lunch Break</td>
        </tr>
        <tr>
            <td rowspan="2">1:00 PM - 2:00 AM </td>
            <td>Session G</td>
            <td rowspan="2">Session H</td>
            <td>Session I</td>
            <td>Session J</td>
        </tr>
        <tr>
            <td>Session K</td>
            <td>Session L</td>
            <td>Session M</td>
        </tr>
    </table>
</body>
</html>
